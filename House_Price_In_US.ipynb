# %%
import pandas as pd
from pathlib import Path

zillow_data = pd.read_csv('zillow_house_price.csv')

zillow_data.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName     2000-01-31  \
# 0    102001         0    United States    country       NaN  123201.589358
# 1    394913         1     New York, NY        msa        NY  219438.634519
# 2    753899         2  Los Angeles, CA        msa        CA  226644.663860
# 3    394463         3      Chicago, IL        msa        IL  156108.490933
# 4    394514         4       Dallas, TX        msa        TX  127988.784838
#
#       2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...  \
# 0  123418.340449  123687.143717  124263.673963  124927.191155  ...
# 1  220371.124905  221312.251831  223219.339155  225194.194122  ...
# 2  227488.069574  228611.477941  230846.683212  233291.297037  ...
# 3  156253.001920  156528.225639  157212.913856  158036.511425  ...
# 4  128045.791490  128111.326472  128281.513937  128505.901449  ...
#
#       2023-10-31     2023-11-30     2023-12-31     2024-01-31     2024-02-29  \
# ...

# %%
df = pd.DataFrame(zillow_data)
df.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName     2000-01-31  \
# 0    102001         0    United States    country       NaN  123201.589358
# 1    394913         1     New York, NY        msa        NY  219438.634519
# 2    753899         2  Los Angeles, CA        msa        CA  226644.663860
# 3    394463         3      Chicago, IL        msa        IL  156108.490933
# 4    394514         4       Dallas, TX        msa        TX  127988.784838
#
#       2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...  \
# 0  123418.340449  123687.143717  124263.673963  124927.191155  ...
# 1  220371.124905  221312.251831  223219.339155  225194.194122  ...
# 2  227488.069574  228611.477941  230846.683212  233291.297037  ...
# 3  156253.001920  156528.225639  157212.913856  158036.511425  ...
# 4  128045.791490  128111.326472  128281.513937  128505.901449  ...
#
#       2023-10-31     2023-11-30     2023-12-31     2024-01-31     2024-02-29  \
# ...

# %%
df.dropna(subset = '2000-01-31', inplace = True)
df
# Out:
#      RegionID  SizeRank          RegionName RegionType StateName  \
# 0      102001         0       United States    country       NaN
# 1      394913         1        New York, NY        msa        NY
# 2      753899         2     Los Angeles, CA        msa        CA
# 3      394463         3         Chicago, IL        msa        IL
# 4      394514         4          Dallas, TX        msa        TX
# ..        ...       ...                 ...        ...       ...
# 865    395135       903      Storm Lake, IA        msa        IA
# 866    394498       905         Cordele, GA        msa        GA
# 871    753925       910  Vineyard Haven, MA        msa        MA
# 879    394594       923      Fitzgerald, GA        msa        GA
# 892    753874       937           Craig, CO        msa        CO
#
#         2000-01-31     2000-02-29     2000-03-31     2000-04-30  \
# 0    123201.589358  123418.340449  123687.143717  124263.673963
# ...

# %%
df = df.drop(columns=['RegionID', 'SizeRank', 'RegionType', 'StateName'])
df=df.rename(columns=lambda x:x[:4])
df
# Out:
#                    Regi           2000           2000           2000  \
# 0         United States  123201.589358  123418.340449  123687.143717
# 1          New York, NY  219438.634519  220371.124905  221312.251831
# 2       Los Angeles, CA  226644.663860  227488.069574  228611.477941
# 3           Chicago, IL  156108.490933  156253.001920  156528.225639
# 4            Dallas, TX  127988.784838  128045.791490  128111.326472
# ..                  ...            ...            ...            ...
# 865      Storm Lake, IA   73883.787364   74070.923759   74196.373568
# 866         Cordele, GA   65154.305563   65368.883067   65493.880166
# 871  Vineyard Haven, MA  337239.617885  338659.260121  339972.878819
# 879      Fitzgerald, GA   55692.325039   55456.414857   55366.118935
# 892           Craig, CO  100142.171755  100398.242291  100874.978550
#
#               2000           2000           2000           2000  \
# 0    124263.673963  124927.191155  125638.571013  126392.061619
# ...

# %%
df.to_csv("house_price_clean.csv")

# %%
house_data = pd.read_csv('house_price_clean.csv')
house_data.head()
# Out:
#   State    2005    2010    2015    2020    2023
# 0    NY  320312  439514  395500  480347  602236
# 1    CA  354098  500757  443900  626101  864958
# 2    IL  197090  234585  185638  232818  293573
# 3    TX  138425  152773  159478  240776  353493
# 4    TX  133107  151978  158332  213454  290996

# %%
house_data = house_data.groupby('State').mean().round(0)
house_data
# Out:
#            2005      2010      2015      2020      2023
# State
# AK     178500.0  249762.0  267850.0  305460.0  357237.0
# AL     118128.0  146919.0  133735.0  159227.0  216684.0
# AR      86684.0  105293.0  103688.0  120755.0  161040.0
# AZ     137055.0  201728.0  163472.0  227780.0  360426.0
# CA     323972.0  407692.0  348032.0  521382.0  713648.0
# CO     207454.0  257497.0  260353.0  367764.0  552636.0
# CT     234716.0  303797.0  252572.0  269890.0  362904.0
# DC     267693.0  377111.0  348278.0  415825.0  527099.0
# FL     137643.0  186377.0  143574.0  205686.0  321288.0
# GA     103301.0  118558.0  103680.0  125772.0  186795.0
# HI     272901.0  466662.0  467590.0  625676.0  872853.0
# IA     107279.0  121993.0  126890.0  157570.0  205594.0
# ID     129249.0  179266.0  155076.0  220554.0  389468.0
# IL     103193.0  120563.0  108486.0  121030.0  150472.0
# IN     117672.0  126536.0  127154.0  156832.0  220312.0
# KS      93111.0  110797.0  109241.0  126438.0  179380.0
# ...

# %%
house_data.to_csv("house_price_state_clean.csv")

# %%
house_data.swapaxes("index", "columns") 
house_data.head()
# Out:
#            2005      2010      2015      2020      2023
# State
# AK     178500.0  249762.0  267850.0  305460.0  357237.0
# AL     118128.0  146919.0  133735.0  159227.0  216684.0
# AR      86684.0  105293.0  103688.0  120755.0  161040.0
# AZ     137055.0  201728.0  163472.0  227780.0  360426.0
# CA     323972.0  407692.0  348032.0  521382.0  713648.0

# %%
house_data.plot(kind = "line")
# Out:
# <Axes: xlabel='State'>
